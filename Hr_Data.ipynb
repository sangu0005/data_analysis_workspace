# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Hr_data.csv')

# %%
df
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
# ...

# %%
df.isna().sum()
# Out:
# employee_id              0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# department               0
# salary                   0
# dtype: int64

# %%
df.head()
# Out:
#    employee_id  number_project  average_montly_hours  time_spend_company  \
# 0         1003               2                   157                   3
# 1         1005               5                   262                   6
# 2         1486               7                   272                   4
# 3         1038               5                   223                   5
# 4         1057               2                   159                   3
#
#    Work_accident  left  promotion_last_5years department  salary
# 0              0     1                      0      sales     low
# 1              0     1                      0      sales  medium
# 2              0     1                      0      sales  medium
# 3              0     1                      0      sales     low
# 4              0     1                      0      sales     low

# %%
df.columns
# Out:
# Index(['employee_id', 'number_project', 'average_montly_hours',
#        'time_spend_company', 'Work_accident', 'left', 'promotion_last_5years',
#        'department', 'salary'],
#       dtype='str')

# %%
df.rename(columns={'employee_id' : 'Employee_ID', 'number_project' : 'Number_of_Projects', 'average_montly_hours' : 'Average_Monthly_Hours',
       'time_spend_company' : 'Time_Spent_in_Company', 'Work_accident' : 'Work_Accident', 'left' : 'Left', 'promotion_last_5years' : 'Promoted_in_Last_5_Years',
       'department' : 'Department', 'salary' : 'Salary '}, inplace=True)

# %%
df
# Out:
#        Employee_ID  Number_of_Projects  Average_Monthly_Hours  \
# 0             1003                   2                    157
# 1             1005                   5                    262
# 2             1486                   7                    272
# 3             1038                   5                    223
# 4             1057                   2                    159
# ...            ...                 ...                    ...
# 14994        87670                   2                    151
# 14995        87673                   2                    160
# 14996        87679                   2                    143
# 14997        87681                   6                    280
# 14998        87684                   2                    158
#
#        Time_Spent_in_Company  Work_Accident  Left  Promoted_in_Last_5_Years  \
# 0                          3              0     1                         0
# ...

# %%
df['Department'].value_counts()
# Out:
# Department
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Number_of_Projects', 'Average_Monthly_Hours',
#        'Time_Spent_in_Company', 'Work_Accident', 'Left',
#        'Promoted_in_Last_5_Years', 'Department', 'Salary '],
#       dtype='str')

# %%
df.loc[df['Salary '] == 'low', ['Employee_ID','Department', 'Salary ']]
# Out:
#        Employee_ID Department Salary
# 0             1003      sales     low
# 3             1038      sales     low
# 4             1057      sales     low
# 5             1060      sales     low
# 6             1061      sales     low
# ...            ...        ...     ...
# 14994        87670    support     low
# 14995        87673    support     low
# 14996        87679    support     low
# 14997        87681    support     low
# 14998        87684    support     low
#
# [7316 rows x 3 columns]

# %%
df.iloc[0:5, 0:5]
# Out:
#    Employee_ID  Number_of_Projects  Average_Monthly_Hours  \
# 0         1003                   2                    157
# 1         1005                   5                    262
# 2         1486                   7                    272
# 3         1038                   5                    223
# 4         1057                   2                    159
#
#    Time_Spent_in_Company  Work_Accident
# 0                      3              0
# 1                      6              0
# 2                      4              0
# 3                      5              0
# 4                      3              0

# %%
df['Department'].unique()
# Out:
# <ArrowStringArray>
# [      'sales',  'accounting',          'hr',   'technical',     'support',
#   'management',          'IT', 'product_mng',   'marketing',       'RandD']
# Length: 10, dtype: str

# %%
df.loc[df['Department'].isin(['Sales', 'IT'])]
# Out:
#        Employee_ID  Number_of_Projects  Average_Monthly_Hours  \
# 61            1399                   7                    308
# 62            1404                   6                    244
# 63            1413                   2                    132
# 64           42423                   6                    286
# 65            1424                   6                    161
# ...            ...                 ...                    ...
# 14930        87284                   6                    268
# 14931        87288                   5                    240
# 14932        87294                   2                    127
# 14933        87308                   7                    264
# 14938        45511                   4                    271
#
#        Time_Spent_in_Company  Work_Accident  Left  Promoted_in_Last_5_Years  \
# 61                         4              0     1                         0
# ...

# %%
df['Department'].value_counts()
# Out:
# Department
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: count, dtype: int64

# %%
grp = df.groupby('Department')

# %%
grp.groups
# Out:
# {'IT': [61, 62, 63, 64, 65, 70, 138, 139, 140, 141, 142, 147, 214, 215, 216, 217, 218, 223, 291, 292, 293, 294, 295, 300, 367, 368, 369, 370, 371, 376, 443, 444, 445, 446, 447, 452, 519, 520, 521, 522, 523, 528, 595, 596, 597, 598, 599, 604, 671, 672, 673, 674, 675, 680, 747, 748, 749, 750, 751, 756, 823, 824, 825, 826, 827, 832, 899, 900, 901, 902, 903, 908, 975, 976, 977, 978, 979, 984, 1051, 1052, 1053, 1054, 1055, 1060, 1127, 1128, 1129, 1130, 1131, 1136, 1204, 1205, 1206, 1207, 1208, 1213, 1214, 1215, 1216, 1281, ...], 'RandD': [301, 302, 303, 304, 305, 453, 454, 455, 456, 457, 605, 606, 607, 608, 609, 833, 834, 835, 836, 837, 985, 986, 987, 988, 989, 1061, 1062, 1063, 1064, 1065, 1217, 1218, 1219, 1291, 1292, 1293, 1294, 1295, 1296, 1368, 1369, 1370, 1371, 1372, 1373, 1445, 1446, 1447, 1448, 1449, 1450, 1522, 1523, 1524, 1525, 1526, 1598, 1599, 1600, 1601, 1602, 1675, 1676, 1677, 1678, 1679, 1751, 1752, 1753, 1754, 1755, 1827, 1828, 1829, 1830, 1831, 1903, 1904, 1905, 1906, 190
# ...

# %%
grp_it = grp.get_group('IT')

# %%
grp_sales = grp.get_group('sales')

# %%
grp_it['Average_Monthly_Hours'].mean()
# Out:
# np.float64(202.2159739201304)

# %%
grp_sales.max()
# Out:
# Employee_ID                  99602
# Number_of_Projects               7
# Average_Monthly_Hours          310
# Time_Spent_in_Company           10
# Work_Accident                    1
# Left                             1
# Promoted_in_Last_5_Years         1
# Department                   sales
# Salary                      medium
# dtype: object
