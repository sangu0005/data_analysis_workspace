# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(1,8)
y = np.arange(9,16)
plt.plot(x,y)
plt.grid()
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Simple Plot')
# Out:
# Text(0.5, 1.0, 'Simple Plot')
