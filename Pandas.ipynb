# %%
import pandas as pd

# %%
pd.Series([10,20,30])
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
data = [['Sangu', 21, 'DS'],['Eren', 20, 'BSc']]
dff = pd.DataFrame(data, index = ['a', 'b'], columns = ['Names', 'Age', 'Branch'])

# %%
dff['Names']
# Out:
# a    Sangu
# b     Eren
# Name: Names, dtype: str

# %%
dff.loc['a', 'Names'] = 'Sanji'

# %%
dff
# Out:
#    Names  Age Branch
# a  Sanji   21     DS
# b   Eren   20    BSc

# %%
df = pd.read_csv('Titanic.csv')

# %%
df.to_csv("csv", index=False)

# %%
df.to_csv("Titanic.csv", index=False)

# %%
df.rename(columns={'pclass':'Passenger Class','cabin':'Cabin','ticket':'Ticket','embarked':'Embarked','survived':'Survived','name':'Full_Name','sex':'Gender', 'age':'Age', 'fare':'Fare','sibsp':'Siblings/Spouses', 'parch':'Parents/Children'}, inplace=True)

# %%
df
# Out:
#       Passenger Class                                        Full_Name  \
# 0                   1                    Allen, Miss. Elisabeth Walton
# 1                   1                   Allison, Master. Hudson Trevor
# 2                   1                     Allison, Miss. Helen Loraine
# 3                   1             Allison, Mr. Hudson Joshua Creighton
# 4                   1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...               ...                                              ...
# 1304                3                             Zabour, Miss. Hileni
# 1305                3                            Zabour, Miss. Thamine
# 1306                3                        Zakarian, Mr. Mapriededer
# 1307                3                              Zakarian, Mr. Ortin
# 1308                3                               Zimmerman, Mr. Leo
#
#       Gender      Age  Siblings/Spouses  Parents/Children  Ticket      Fare  \
# ...

# %%
df.head()
# Out:
#    Passenger Class                                        Full_Name  Gender  \
# 0                1                    Allen, Miss. Elisabeth Walton  female
# 1                1                   Allison, Master. Hudson Trevor    male
# 2                1                     Allison, Miss. Helen Loraine  female
# 3                1             Allison, Mr. Hudson Joshua Creighton    male
# 4                1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        Age  Siblings/Spouses  Parents/Children  Ticket      Fare    Cabin  \
# 0  29.0000                 0                 0   24160  211.3375       B5
# 1   0.9167                 1                 2  113781  151.5500  C22 C26
# 2   2.0000                 1                 2  113781  151.5500  C22 C26
# 3  30.0000                 1                 2  113781  151.5500  C22 C26
# 4  25.0000                 1                 2  113781  151.5500  C22 C26
#
#   Embarked  Survived
# 0        S         1
# ...

# %%
df.tail()
# Out:
#       Passenger Class                  Full_Name  Gender   Age  \
# 1304                3       Zabour, Miss. Hileni  female  14.5
# 1305                3      Zabour, Miss. Thamine  female   NaN
# 1306                3  Zakarian, Mr. Mapriededer    male  26.5
# 1307                3        Zakarian, Mr. Ortin    male  27.0
# 1308                3         Zimmerman, Mr. Leo    male  29.0
#
#       Siblings/Spouses  Parents/Children  Ticket     Fare Cabin Embarked  \
# 1304                 1                 0    2665  14.4542   NaN        C
# 1305                 1                 0    2665  14.4542   NaN        C
# 1306                 0                 0    2656   7.2250   NaN        C
# 1307                 0                 0    2670   7.2250   NaN        C
# 1308                 0                 0  315082   7.8750   NaN        S
#
#       Survived
# 1304         0
# 1305         0
# 1306         0
# 1307         0
# 1308         0

# %%
df.columns
# Out:
# Index(['Passenger Class', 'Full_Name', 'Gender', 'Age', 'Siblings/Spouses',
#        'Parents/Children', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Survived'],
#       dtype='str')

# %%
df['Gender'].unique()
# Out:
# <ArrowStringArray>
# ['female', 'male']
# Length: 2, dtype: str

# %%
df['Gender'].value_counts()
# Out:
# Gender
# male      843
# female    466
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (1309, 11)

# %%
#loc >>> To fetch a row or column by label
df.loc[0]
# Out:
# Passenger Class                                 1
# Full_Name           Allen, Miss. Elisabeth Walton
# Gender                                     female
# Age                                          29.0
# Siblings/Spouses                                0
# Parents/Children                                0
# Ticket                                      24160
# Fare                                     211.3375
# Cabin                                          B5
# Embarked                                        S
# Survived                                        1
# Name: 0, dtype: object

# %%
df.loc[0:5, ['Full_Name', 'Gender', 'Age']]
# Out:
#                                          Full_Name  Gender      Age
# 0                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1                   Allison, Master. Hudson Trevor    male   0.9167
# 2                     Allison, Miss. Helen Loraine  female   2.0000
# 3             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
# 5                              Anderson, Mr. Harry    male  48.0000

# %%
df.loc[df['Age'] > 30, ['Full_Name', 'Gender', 'Age']]
# Out:
#                                             Full_Name  Gender   Age
# 5                                 Anderson, Mr. Harry    male  48.0
# 6                   Andrews, Miss. Kornelia Theodosia  female  63.0
# 7                              Andrews, Mr. Thomas Jr    male  39.0
# 8       Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.0
# 9                             Artagaveytia, Mr. Ramon    male  71.0
# ...                                               ...     ...   ...
# 1286  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)  female  38.0
# 1287                 Widegren, Mr. Carl/Charles Peter    male  51.0
# 1290                 Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 1298                        Wittevrongel, Mr. Camille    male  36.0
# 1301                             Youseff, Mr. Gerious    male  45.5
#
# [437 rows x 3 columns]

# %%
df.loc[((df['Age'] > 30) | (df['Gender'] == 'male')) & ((df['Embarked'] == 'S') | (df['Embarked'] == 'C'))].head()
# Out:
#    Passenger Class                             Full_Name  Gender      Age  \
# 1                1        Allison, Master. Hudson Trevor    male   0.9167
# 3                1  Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 5                1                   Anderson, Mr. Harry    male  48.0000
# 6                1     Andrews, Miss. Kornelia Theodosia  female  63.0000
# 7                1                Andrews, Mr. Thomas Jr    male  39.0000
#
#    Siblings/Spouses  Parents/Children  Ticket      Fare    Cabin Embarked  \
# 1                 1                 2  113781  151.5500  C22 C26        S
# 3                 1                 2  113781  151.5500  C22 C26        S
# 5                 0                 0   19952   26.5500      E12        S
# 6                 1                 0   13502   77.9583       D7        S
# 7                 0                 0  112050    0.0000      A36        S
#
#    Survived
# 1         1
# 3         0
# 5         1
# 6         1
# ...

# %%
df.loc[[0, 1, 2], ['Full_Name', 'Gender', 'Age']]
# Out:
#                         Full_Name  Gender      Age
# 0   Allen, Miss. Elisabeth Walton  female  29.0000
# 1  Allison, Master. Hudson Trevor    male   0.9167
# 2    Allison, Miss. Helen Loraine  female   2.0000

# %%
df.loc[df['Passenger Class'].isin([1,2]) & df['Cabin'].isin(['B5','C22 C26'])]
# Out:
#      Passenger Class                                        Full_Name  Gender  \
# 0                  1                    Allen, Miss. Elisabeth Walton  female
# 1                  1                   Allison, Master. Hudson Trevor    male
# 2                  1                     Allison, Miss. Helen Loraine  female
# 3                  1             Allison, Mr. Hudson Joshua Creighton    male
# 4                  1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 193                1                Madill, Miss. Georgette Alexandra  female
#
#          Age  Siblings/Spouses  Parents/Children  Ticket      Fare    Cabin  \
# 0    29.0000                 0                 0   24160  211.3375       B5
# 1     0.9167                 1                 2  113781  151.5500  C22 C26
# 2     2.0000                 1                 2  113781  151.5500  C22 C26
# 3    30.0000                 1                 2  113781  151.5500  C22 C26
# ...

# %%
df.loc[df['Age'].between(20, 30, inclusive='right')]
# Out:
#       Passenger Class                                        Full_Name  \
# 0                   1                    Allen, Miss. Elisabeth Walton
# 3                   1             Allison, Mr. Hudson Joshua Creighton
# 4                   1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 12                  1                    Aubart, Mme. Leontine Pauline
# 13                  1                     Barber, Miss. Ellen "Nellie"
# ...               ...                                              ...
# 1296                3                                 Wirz, Mr. Albert
# 1299                3                              Yasbeck, Mr. Antoni
# 1306                3                        Zakarian, Mr. Mapriededer
# 1307                3                              Zakarian, Mr. Ortin
# 1308                3                               Zimmerman, Mr. Leo
#
#       Gender   Age  Siblings/Spouses  Parents/Children    Ticket      Fare  \
# ...

# %%
# df.iloc[0]
df.iloc[0 : 8]
# Out:
#    Passenger Class                                        Full_Name  Gender  \
# 0                1                    Allen, Miss. Elisabeth Walton  female
# 1                1                   Allison, Master. Hudson Trevor    male
# 2                1                     Allison, Miss. Helen Loraine  female
# 3                1             Allison, Mr. Hudson Joshua Creighton    male
# 4                1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5                1                              Anderson, Mr. Harry    male
# 6                1                Andrews, Miss. Kornelia Theodosia  female
# 7                1                           Andrews, Mr. Thomas Jr    male
#
#        Age  Siblings/Spouses  Parents/Children  Ticket      Fare    Cabin  \
# 0  29.0000                 0                 0   24160  211.3375       B5
# 1   0.9167                 1                 2  113781  151.5500  C22 C26
# ...
